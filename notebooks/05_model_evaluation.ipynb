# %% [markdown]
# # 05 – Model Evaluation and Conclusions
#
# ## Project Overview
#
# In this notebook, I summarize the model performance results from the salary prediction pipeline and reflect on the strengths, limitations, and future directions of the project.
